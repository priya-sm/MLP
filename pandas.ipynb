# %% [markdown]
# #Topics
# 1. Basic Data Inspection
# 2. Data Selection
# 3. .loc and .iloc
# 4. lambda function
# 5. AND operators
# 6. OR operation
# 7. Adding and dropping column

# %%
import pandas as pd
from sklearn.datasets import load_diabetes

# %%
diabetes=load_diabetes(as_frame=True)
df= diabetes['data']
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %% [markdown]
# >***as_frame=True***
#
# - This argument specifies that the data should be returned as a Pandas DataFrame instead of a NumPy array or a Bunch object. This makes it easier to work with the data using Pandas' data analysis tools.

# %% [markdown]
# #**Basic Data Inspection**

# %% [markdown]
# **1. head():**
# - *Purpose:* Returns the first n rows of a DataFrame or Series.
# - *Syntax:* DataFrame.head(n) or Series.head(n)
# - *Parameters:*
# n: The number of rows to return (default is 5).

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.head(n=5)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.head(3)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930

# %% [markdown]
# **2. tail():**
#
# - *Purpose:* Returns the last n rows of a DataFrame or Series.
# - *Syntax:* DataFrame.tail(n) or Series.tail(n)
# - *Parameters:*
# n: The number of rows to return (default is 5).

# %%
df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
df.tail(n=1)
# Out:
#           age       sex      bmi        bp       s1        s2        s3  \
# 441 -0.045472 -0.044642 -0.07303 -0.081413  0.08374  0.027809  0.173816
#
#            s4        s5        s6
# 441 -0.039493 -0.004222  0.003064

# %%
df.tail(2)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %% [markdown]
# **3.shape**
# - The shape attribute in Pandas is used to determine the dimensions of a DataFrame or Series. It returns a tuple containing the number of rows and columns in the object.

# %%
df.shape
# Out:
# (442, 10)

# %% [markdown]
# **4. columns Attribute:**
#
# - The most direct way to get a list of column names is to use the columns attribute of the DataFrame:

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %% [markdown]
# **5. info()**
# - *Shape*: The number of rows and columns in the DataFrame.
# - *Dtypes*: The data types of each column.
# - *Memory Usage*: The amount of memory used by the DataFrame.
# - *Non-Null Count*: The number of non-null values in each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %% [markdown]
# **5. Summary statistics:**
#
# ***.describe():***
# - Provides a comprehensive summary of the numerical columns in a DataFrame.
# - Includes statistics like count, mean, standard deviation, minimum, 25th percentile, 50th percentile (median), 75th percentile, and maximum.
#
# **.mean():** Calculates the mean (average) of the values in a Series or DataFrame.
#
# **.median():**Calculates the median (middle value) of the values in a Series or DataFrame.
#
# **.mode():** Returns the mode (most frequent value) of the values in a Series or DataFrame.
#
# **.min() and .max():** Calculate the minimum and maximum values in a Series or DataFrame.
#
# **.std():** Calculates the standard deviation of the values in a Series or DataFrame.
#
# **.var():** Calculates the variance of the values in a Series or DataFrame.

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
df.describe().T
# Out:
#      count          mean       std       min       25%       50%       75%  \
# age  442.0 -2.511817e-19  0.047619 -0.107226 -0.037299  0.005383  0.038076
# sex  442.0  1.230790e-17  0.047619 -0.044642 -0.044642 -0.044642  0.050680
# bmi  442.0 -2.245564e-16  0.047619 -0.090275 -0.034229 -0.007284  0.031248
# bp   442.0 -4.797570e-17  0.047619 -0.112399 -0.036656 -0.005670  0.035644
# s1   442.0 -1.381499e-17  0.047619 -0.126781 -0.034248 -0.004321  0.028358
# s2   442.0  3.918434e-17  0.047619 -0.115613 -0.030358 -0.003819  0.029844
# s3   442.0 -5.777179e-18  0.047619 -0.102307 -0.035117 -0.006584  0.029312
# s4   442.0 -9.042540e-18  0.047619 -0.076395 -0.039493 -0.002592  0.034309
# s5   442.0  9.293722e-17  0.047619 -0.126097 -0.033246 -0.001947  0.032432
# s6   442.0  1.130318e-17  0.047619 -0.137767 -0.033179 -0.001078  0.027917
#
#           max
# age  0.110727
# sex  0.050680
# bmi  0.170555
# bp   0.132044
# s1   0.153914
# s2   0.198788
# s3   0.181179
# s4   0.185234
# ...

# %%
df.describe(percentiles=[0.2,0.6,0.8])
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 20%   -4.547248e-02 -4.464164e-02 -4.048038e-02 -4.009893e-02 -3.871969e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 60%    1.628068e-02  5.068012e-02  5.218854e-03  8.100982e-03  8.062710e-03
# 80%    4.170844e-02  5.068012e-02  4.229559e-02  4.941519e-02  3.943444e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# ...

# %% [markdown]
# # **Data Selection**

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
df['age']
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %%
df['age'][1]
# Out:
# -0.0018820165277906047

# %%
df[['age','sex','bmi']]
# Out:
#           age       sex       bmi
# 0    0.038076  0.050680  0.061696
# 1   -0.001882 -0.044642 -0.051474
# 2    0.085299  0.050680  0.044451
# 3   -0.089063 -0.044642 -0.011595
# 4    0.005383 -0.044642 -0.036385
# ..        ...       ...       ...
# 437  0.041708  0.050680  0.019662
# 438 -0.005515  0.050680 -0.015906
# 439  0.041708  0.050680 -0.015906
# 440 -0.045472 -0.044642  0.039062
# 441 -0.045472 -0.044642 -0.073030
#
# [442 rows x 3 columns]

# %%
df[['age','sex','bmi']][:4] #first 4 values
# Out:
#         age       sex       bmi
# 0  0.038076  0.050680  0.061696
# 1 -0.001882 -0.044642 -0.051474
# 2  0.085299  0.050680  0.044451
# 3 -0.089063 -0.044642 -0.011595

# %%
df[['age','sex','bmi']][-4:]#last 4 values
# Out:
#           age       sex       bmi
# 438 -0.005515  0.050680 -0.015906
# 439  0.041708  0.050680 -0.015906
# 440 -0.045472 -0.044642  0.039062
# 441 -0.045472 -0.044642 -0.073030

# %%
df['age'][100:110]
# Out:
# 100    0.016281
# 101    0.016281
# 102   -0.092695
# 103    0.059871
# 104   -0.027310
# 105    0.023546
# 106   -0.096328
# 107    0.027178
# 108    0.019913
# 109    0.038076
# Name: age, dtype: float64

# %%
df[['age','sex','bmi']][100:110]
# Out:
#           age       sex       bmi
# 100  0.016281 -0.044642  0.017506
# 101  0.016281  0.050680 -0.045007
# 102 -0.092695 -0.044642  0.028284
# 103  0.059871  0.050680  0.041218
# 104 -0.027310 -0.044642  0.064930
# 105  0.023546  0.050680 -0.032073
# 106 -0.096328 -0.044642 -0.076264
# 107  0.027178 -0.044642  0.049840
# 108  0.019913  0.050680  0.045529
# 109  0.038076  0.050680 -0.009439

# %% [markdown]
# # **.loc and .iloc**

# %%
df.iloc[0]
# Out:
# age    0.038076
# sex    0.050680
# bmi    0.061696
# bp     0.021872
# s1    -0.044223
# s2    -0.034821
# s3    -0.043401
# s4    -0.002592
# s5     0.019907
# s6    -0.017646
# Name: 0, dtype: float64

# %%
df.iloc[111]
# Out:
# age    0.019913
# sex   -0.044642
# bmi    0.004572
# bp    -0.026328
# s1     0.023198
# s2     0.010273
# s3     0.067048
# s4    -0.039493
# s5    -0.023647
# s6    -0.046641
# Name: 111, dtype: float64

# %%
df['age'].iloc[111]
# Out:
# 0.01991321417832592

# %%
df.iloc[4,[0,5,7,8]]
# Out:
# age    0.005383
# s2     0.015596
# s4    -0.002592
# s5    -0.031988
# Name: 4, dtype: float64

# %%
df.loc[111,'age']
# Out:
# 0.01991321417832592

# %%
age=df.loc[df.age>0.041708]
age
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 7    0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 14   0.045341 -0.044642 -0.025607 -0.012556  0.017694 -0.000061  0.081775
# 17   0.070769  0.050680  0.012117  0.056301  0.034206  0.049416 -0.039719
# ..        ...       ...       ...       ...       ...       ...       ...
# 414  0.081666  0.050680  0.006728 -0.004534  0.109883  0.117056 -0.032356
# 428  0.048974  0.050680  0.088642  0.087287  0.035582  0.021546 -0.024993
# 431  0.070769  0.050680 -0.030996  0.021872 -0.037344 -0.047034  0.033914
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
#
#            s4        s5        s6
# 2   -0.002592  0.002861 -0.025930
# ...

# %%
#same as above but without loc
age1=df[df.age>0.041708]
age1
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 7    0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 14   0.045341 -0.044642 -0.025607 -0.012556  0.017694 -0.000061  0.081775
# 17   0.070769  0.050680  0.012117  0.056301  0.034206  0.049416 -0.039719
# ..        ...       ...       ...       ...       ...       ...       ...
# 414  0.081666  0.050680  0.006728 -0.004534  0.109883  0.117056 -0.032356
# 428  0.048974  0.050680  0.088642  0.087287  0.035582  0.021546 -0.024993
# 431  0.070769  0.050680 -0.030996  0.021872 -0.037344 -0.047034  0.033914
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
#
#            s4        s5        s6
# 2   -0.002592  0.002861 -0.025930
# ...

# %% [markdown]
# #**lambda function**
#
# Syntax:
# lambda arguments : expression

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
df_lambda=lambda df:df['age']*100
df_lambda(df)
# Out:
# 0      3.807591
# 1     -0.188202
# 2      8.529891
# 3     -8.906294
# 4      0.538306
#          ...
# 437    4.170844
# 438   -0.551455
# 439    4.170844
# 440   -4.547248
# 441   -4.547248
# Name: age, Length: 442, dtype: float64

# %%
df_lambda1= lambda df: df*1000
df_lambda1(df)
# Out:
#            age        sex        bmi         bp         s1         s2  \
# 0    38.075906  50.680119  61.696207  21.872386 -44.223498 -34.820763
# 1    -1.882017 -44.641637 -51.474061 -26.327528  -8.448724 -19.163340
# 2    85.298906  50.680119  44.451213  -5.670422 -45.599451 -34.194466
# 3   -89.062939 -44.641637 -11.595015 -36.656081  12.190569  24.990593
# 4     5.383060 -44.641637 -36.384692  21.872386   3.934852  15.596140
# ..         ...        ...        ...        ...        ...        ...
# 437  41.708445  50.680119  19.661536  59.743746  -5.696818  -2.566471
# 438  -5.514555  50.680119 -15.906263 -67.641740  49.341296  79.165277
# 439  41.708445  50.680119 -15.906263  17.293394 -37.343734 -13.839816
# 440 -45.472478 -44.641637  39.062153   1.215280  16.318427  15.282991
# 441 -45.472478 -44.641637 -73.030303 -81.413144  83.740117  27.808930
#
#              s3         s4         s5         s6
# 0    -43.400846  -2.592262  19.907486 -17.646125
# ...

# %% [markdown]
# #**AND operators**

# %%
and_condition=(df['age']<0.5)&(df['age']>0.1)

# %%
and_condition
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 437    False
# 438    False
# 439    False
# 440    False
# 441    False
# Name: age, Length: 442, dtype: bool

# %%
df[and_condition]
# Out:
#           age      sex       bmi        bp        s1        s2        s3  \
# 204  0.110727  0.05068  0.006728  0.028758 -0.027712 -0.007264 -0.047082
# 402  0.110727  0.05068 -0.033151 -0.022885 -0.004321  0.020293 -0.061809
#
#            s4        s5        s6
# 204  0.034309  0.002004  0.077622
# 402  0.071210  0.015568  0.044485

# %% [markdown]
# #**OR operation**

# %%
or_condition=(df['age']>0.5) | (df['age']>0.1)
df[or_condition]
# Out:
#           age      sex       bmi        bp        s1        s2        s3  \
# 204  0.110727  0.05068  0.006728  0.028758 -0.027712 -0.007264 -0.047082
# 402  0.110727  0.05068 -0.033151 -0.022885 -0.004321  0.020293 -0.061809
#
#            s4        s5        s6
# 204  0.034309  0.002004  0.077622
# 402  0.071210  0.015568  0.044485

# %% [markdown]
# #**Adding and dropping column**

# %%
df['new_col']=df['s6']*100
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6   new_col
# 0 -0.002592  0.019907 -0.017646 -1.764613
# 1 -0.039493 -0.068332 -0.092204 -9.220405
# 2 -0.002592  0.002861 -0.025930 -2.593034
# 3  0.034309  0.022688 -0.009362 -0.936191
# 4 -0.002592 -0.031988 -0.046641 -4.664087

# %%
df = df.drop(columns=['new_col'])
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641
